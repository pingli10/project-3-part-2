# %%
import pandas as pd 
import numpy as np

# %%
data_final_merged = 'Data/final_merged_data.csv.gz'
data_basics = 'Data/title_basics.csv.gz'
data_rating = 'Data/title.ratings.tsv.gz'

# %%
df = pd.read_csv(data)
db = pd.read_csv(data_basics)
df_rating = pd.read_csv(data_rating)

# %%
df.head()
# Out:
#      imdb_id  adult                     backdrop_path  \
# 0  tt0118694    0.0  /n4GJFGzsc7NinI1VeGDXIcQjtU2.jpg
# 1  tt0119273    0.0  /f5C03doOWiauu37bToKXtpgP5bS.jpg
# 2  tt0120467    0.0  /knok3mNReKqPTplnnqz7E4dd7mD.jpg
# 3  tt0120630    0.0  /sPAwM8WxMdXNlqeP4F9DMe9LYoY.jpg
# 4  tt0120753    0.0                               NaN
#
#                                belongs_to_collection      budget  \
# 0                                                NaN    150000.0
# 1  {'id': 141086, 'name': 'Heavy Metal Collection...  15000000.0
# 2                                                NaN    120000.0
# 3  {'id': 718551, 'name': 'Chicken Run Collection...  45000000.0
# 4                                                NaN   8000000.0
#
#                                               genres  \
# 0  [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...
# 1  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 2  [{'id': 18, 'name': 'Drama'}, {'id': 27, 'name...
# 3  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 4  [{'id': 18, 'name': 'Drama'}, {'id': 53, 'name...
#
#                                homepage       id original_language  \
# 0  http://www.wkw-inthemoodforlove.com/    843.0                cn
# 1                                   NaN  16225.0                en
# 2                                   NaN  19085.0                en
# 3                                   NaN   7443.0                en
# 4                                   NaN    318.0                en
#
#              original_title  ...      revenue  runtime  \
# 0                      花樣年華  ...   12854953.0     99.0
# 1          Heavy Metal 2000  ...          0.0     88.0
# 2                    Vulgar  ...      14904.0     87.0
# 3               Chicken Run  ...  224834564.0     84.0
# 4  The Million Dollar Hotel  ...     105983.0    122.0
#
#                                     spoken_languages    status  \
# 0  [{'english_name': 'Cantonese', 'iso_639_1': 'c...  Released
# 1  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 2  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 3  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 4  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
#
#                                              tagline  \
# 0  Feel the heat, keep the feeling burning, let t...
# 1  not to survive the fight in the external world...
# 2   Everyone loves a clown... some more than others.
# 3  This ain't no chick flick. It's poultry in mot...
# 4                    Everyone has something to hide.
#
#                       title  video  vote_average vote_count certification
# 0      In the Mood for Love    0.0         8.108     1982.0            PG
# 1          Heavy Metal 2000    0.0         6.110      159.0             R
# 2                    Vulgar    0.0         5.400       42.0             R
# 3               Chicken Run    0.0         6.726     4123.0             G
# 4  The Million Dollar Hotel    0.0         5.915      254.0             R
#
# [5 rows x 26 columns]

# %%
db.head()
# Out:
#       tconst titleType                                       primaryTitle  \
# 0  tt0035423     movie                                     Kate & Leopold
# 1  tt0062336     movie  The Tango of the Widower and Its Distorting Mi...
# 2  tt0069049     movie                         The Other Side of the Wind
# 3  tt0088751     movie                                  The Naked Monster
# 4  tt0096056     movie                               Crime and Punishment
#
#                                originalTitle  isAdult  startYear  endYear  \
# 0                             Kate & Leopold        0       2001      NaN
# 1  El Tango del Viudo y Su Espejo Deformante        0       2020      NaN
# 2                 The Other Side of the Wind        0       2018      NaN
# 3                          The Naked Monster        0       2005      NaN
# 4                       Crime and Punishment        0       2002      NaN
#
#    runtimeMinutes                  genres
# 0             118  Comedy,Fantasy,Romance
# 1              70                   Drama
# 2             122                   Drama
# 3             100    Comedy,Horror,Sci-Fi
# 4             126                   Drama

# %%
db_final = db[['tconst','titleType','primaryTitle','startYear','endYear','runtimeMinutes']]
db_final.head()
# Out:
#       tconst titleType                                       primaryTitle  \
# 0  tt0035423     movie                                     Kate & Leopold
# 1  tt0062336     movie  The Tango of the Widower and Its Distorting Mi...
# 2  tt0069049     movie                         The Other Side of the Wind
# 3  tt0088751     movie                                  The Naked Monster
# 4  tt0096056     movie                               Crime and Punishment
#
#    startYear  endYear  runtimeMinutes
# 0       2001      NaN             118
# 1       2020      NaN              70
# 2       2018      NaN             122
# 3       2005      NaN             100
# 4       2002      NaN             126

# %%
## create a col with a list of genres
db['genres_split'] = db['genres'].str.split(',')
db
# Out:
#           tconst titleType                                       primaryTitle  \
# 0      tt0035423     movie                                     Kate & Leopold
# 1      tt0062336     movie  The Tango of the Widower and Its Distorting Mi...
# 2      tt0069049     movie                         The Other Side of the Wind
# 3      tt0088751     movie                                  The Naked Monster
# 4      tt0096056     movie                               Crime and Punishment
# ...          ...       ...                                                ...
# 82661  tt9914942     movie                             Life Without Sara Amat
# 82662  tt9915872     movie                               The Last White Witch
# 82663  tt9916170     movie                                      The Rehearsal
# 82664  tt9916190     movie                                          Safeguard
# 82665  tt9916362     movie                                              Coven
#
#                                    originalTitle  isAdult  startYear  endYear  \
# 0                                 Kate & Leopold        0       2001      NaN
# 1      El Tango del Viudo y Su Espejo Deformante        0       2020      NaN
# 2                     The Other Side of the Wind        0       2018      NaN
# 3                              The Naked Monster        0       2005      NaN
# 4                           Crime and Punishment        0       2002      NaN
# ...                                          ...      ...        ...      ...
# 82661                 La vida sense la Sara Amat        0       2019      NaN
# 82662                  My Girlfriend is a Wizard        0       2019      NaN
# 82663                                   O Ensaio        0       2019      NaN
# 82664                                  Safeguard        0       2020      NaN
# 82665                                   Akelarre        0       2020      NaN
#
#        runtimeMinutes                     genres  \
# 0                 118     Comedy,Fantasy,Romance
# 1                  70                      Drama
# 2                 122                      Drama
# 3                 100       Comedy,Horror,Sci-Fi
# 4                 126                      Drama
# ...               ...                        ...
# 82661              74                      Drama
# 82662              97       Comedy,Drama,Fantasy
# 82663              51                      Drama
# 82664              95  Action,Adventure,Thriller
# 82665              92              Drama,History
#
#                         genres_split
# 0         [Comedy, Fantasy, Romance]
# 1                            [Drama]
# 2                            [Drama]
# 3           [Comedy, Horror, Sci-Fi]
# 4                            [Drama]
# ...                              ...
# 82661                        [Drama]
# 82662       [Comedy, Drama, Fantasy]
# 82663                        [Drama]
# 82664  [Action, Adventure, Thriller]
# 82665               [Drama, History]
#
# [82666 rows x 10 columns]

# %%
exploded_genres = db.explode('genres_split')
exploded_genres
# Out:
#           tconst titleType                                       primaryTitle  \
# 0      tt0035423     movie                                     Kate & Leopold
# 0      tt0035423     movie                                     Kate & Leopold
# 0      tt0035423     movie                                     Kate & Leopold
# 1      tt0062336     movie  The Tango of the Widower and Its Distorting Mi...
# 2      tt0069049     movie                         The Other Side of the Wind
# ...          ...       ...                                                ...
# 82664  tt9916190     movie                                          Safeguard
# 82664  tt9916190     movie                                          Safeguard
# 82664  tt9916190     movie                                          Safeguard
# 82665  tt9916362     movie                                              Coven
# 82665  tt9916362     movie                                              Coven
#
#                                    originalTitle  isAdult  startYear  endYear  \
# 0                                 Kate & Leopold        0       2001      NaN
# 0                                 Kate & Leopold        0       2001      NaN
# 0                                 Kate & Leopold        0       2001      NaN
# 1      El Tango del Viudo y Su Espejo Deformante        0       2020      NaN
# 2                     The Other Side of the Wind        0       2018      NaN
# ...                                          ...      ...        ...      ...
# 82664                                  Safeguard        0       2020      NaN
# 82664                                  Safeguard        0       2020      NaN
# 82664                                  Safeguard        0       2020      NaN
# 82665                                   Akelarre        0       2020      NaN
# 82665                                   Akelarre        0       2020      NaN
#
#        runtimeMinutes                     genres genres_split
# 0                 118     Comedy,Fantasy,Romance       Comedy
# 0                 118     Comedy,Fantasy,Romance      Fantasy
# 0                 118     Comedy,Fantasy,Romance      Romance
# 1                  70                      Drama        Drama
# 2                 122                      Drama        Drama
# ...               ...                        ...          ...
# 82664              95  Action,Adventure,Thriller       Action
# 82664              95  Action,Adventure,Thriller    Adventure
# 82664              95  Action,Adventure,Thriller     Thriller
# 82665              92              Drama,History        Drama
# 82665              92              Drama,History      History
#
# [154505 rows x 10 columns]

# %%
unique_genres = sorted(exploded_genres['genres_split'].unique())
## Making the genre mapper dictionary
genre_ints = range(len(unique_genres))
genre_map = dict(zip(unique_genres, genre_ints))
genre_map
# Out:
# {'Action': 0,
#  'Adult': 1,
#  'Adventure': 2,
#  'Animation': 3,
#  'Biography': 4,
#  'Comedy': 5,
#  'Crime': 6,
#  'Drama': 7,
#  'Family': 8,
#  'Fantasy': 9,
#  'Game-Show': 10,
#  'History': 11,
#  'Horror': 12,
#  'Music': 13,
#  'Musical': 14,
#  'Mystery': 15,
#  'News': 16,
#  'Reality-TV': 17,
#  'Romance': 18,
#  'Sci-Fi': 19,
#  'Short': 20,
#  'Sport': 21,
#  'Talk-Show': 22,
#  'Thriller': 23,
#  'War': 24,
#  'Western': 25}

# %%
## make new integer genre_id and drop string genres
exploded_genres['genre_id'] = exploded_genres['genres_split'].map(genre_map)
exploded_genres = exploded_genres.drop(columns='genres_split')

# %%
title_genres = exploded_genres[['tconst','genre_id']].copy()
title_genres.head()
# Out:
#       tconst  genre_id
# 0  tt0035423         5
# 0  tt0035423         9
# 0  tt0035423        18
# 1  tt0062336         7
# 2  tt0069049         7

# %%
genre_lookup = pd.DataFrame({'Genre_Name':genre_map.keys(),
                            'Genre_ID':genre_map.values()})
genre_lookup.head()
# Out:
#   Genre_Name  Genre_ID
# 0     Action         0
# 1      Adult         1
# 2  Adventure         2
# 3  Animation         3
# 4  Biography         4

# %%
df.columns
# Out:
# Index(['imdb_id', 'adult', 'backdrop_path', 'belongs_to_collection', 'budget',
#        'genres', 'homepage', 'id', 'original_language', 'original_title',
#        'overview', 'popularity', 'poster_path', 'production_companies',
#        'production_countries', 'release_date', 'revenue', 'runtime',
#        'spoken_languages', 'status', 'tagline', 'title', 'video',
#        'vote_average', 'vote_count', 'certification'],
#       dtype='object')

# %%
df_rating.head()
# Out:
#       tconst  averageRating  numVotes
# 0  tt0000001            5.7      1910
# 1  tt0000002            5.8       257
# 2  tt0000005            6.2      2530
# 3  tt0000006            5.1       173
# 4  tt0000007            5.4       789

# %%
import sys
## Set the dataframe index and use index=True 
#db_final.set_index('tconst').to_sql('title_basics',engine,index=True)
#title_genres.set_index('tconst').to_sql('title_genres',engine,index=True)
#genre_lookup.set_index('Genre_ID').to_sql('genres',engine,index=True)
#df.set_index('imdb_id').to_sql('tmdb_data',engine,index=True)
#df_rating.set_index('tconst').to_sql('title_ratings',engine,index=True)

# %%
max_str_len = db_final['tconst'].fillna('').map(len).max()

# %%
## Example
from sqlalchemy.types import *
## Calculate max string lengths for object columns
key_len = title_genres['tconst'].fillna('').map(len).max()
title_len = db_final['primaryTitle'].fillna('').map(len).max()
## Create a schema dictonary using Sqlalchemy datatype objects
df_schema = {
    "tconst": String(key_len+1), 
    "primaryTitle": Text(title_len+1),
    'startYear':Float(),
    'endYear':Float(),
    'runtimeMinutes':Integer()}

# %%
title_genres.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 154505 entries, 0 to 82665
# Data columns (total 2 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   tconst    154505 non-null  object
#  1   genre_id  154505 non-null  int64
# dtypes: int64(1), object(1)
# memory usage: 3.5+ MB

# %%
## Calculate max string lengths for object columns
key_genres = title_genres['tconst'].fillna('').map(len).max()
## Create a schema dictonary using Sqlalchemy datatype objects
title_genres_schema = {
    "tconst": String(key_genres+1), 
    'genre_id':Integer()}

# %%
## Calculate max string lengths for object columns
key_rating = df_rating['tconst'].fillna('').map(len).max()
## Create a schema dictonary using Sqlalchemy datatype objects
df_rating_schema = {
    "tconst": String(key_rating+1), 
    'averageRating':Float(),
    'numVotes':Integer()}

# %%
df_rating.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 477222 entries, 0 to 477221
# Data columns (total 3 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   tconst         477222 non-null  object
#  1   averageRating  477222 non-null  float64
#  2   numVotes       477222 non-null  int64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 10.9+ MB

# %%
from sqlalchemy import create_engine
# create sqlite engine
#engine = create_engine('sqlite:///movie.db', echo=True)
# create connection to engine
#conn = engine.connect()
# Save to sql with dtype and index=False
db_final.to_sql('title_basics',engine,dtype=df_schema,if_exists='replace',index=False)
df_rating.to_sql('title_ratings',engine,dtype=df_rating_schema,if_exists='replace',index=False)
title_genres.to_sql('title_genres',engine,dtype=title_genres_schema,if_exists='replace',index=False)
genre_lookup.set_index('Genre_ID').to_sql('genres',engine,if_exists='replace',index=True)
df.to_sql('tmdb_data',engine,index=True)
# Out:
# 2022-09-26 16:30:46,666 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("title_basics")
# 2022-09-26 16:30:46,667 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2022-09-26 16:30:46,668 INFO sqlalchemy.engine.Engine PRAGMA temp.table_info("title_basics")
# 2022-09-26 16:30:46,668 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2022-09-26 16:30:46,669 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2022-09-26 16:30:46,669 INFO sqlalchemy.engine.Engine
# CREATE TABLE title_basics (
# 	tconst VARCHAR(11),
# 	"titleType" TEXT,
# 	"primaryTitle" TEXT(243),
# 	"startYear" FLOAT,
# 	"endYear" FLOAT,
# 	"runtimeMinutes" INTEGER
# )
#
#
# 2022-09-26 16:30:46,670 INFO sqlalchemy.engine.Engine [no key 0.00041s] ()
# 2022-09-26 16:30:46,671 INFO sqlalchemy.engine.Engine COMMIT
# 2022-09-26 16:30:46,709 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2022-09-26 16:30:47,365 INFO sqlalchemy.engine.Engine INSERT INTO title_basics (tconst, "titleType", "primaryTitle", "startYear", "endYear", "runtimeMinutes") VALUES (?, ?, ?, ?, ?, ?)
# 2022-09-26 16:30:47,366 INFO sqlalchemy.engine.Engine [generated in 0.57200s] (('tt0035423', 'movie', 'Kate & Leopold', 2001.0, None, 118), ('tt0062336', 'movie', 'The Tango of the Widower and Its Distorting Mirror', 2020.0, None, 70), ('tt0069049', 'movie', 'The Other Side of the Wind', 2018.0, None, 122), ('tt0088751', 'movie', 'The Naked Monster', 2005.0, None, 100), ('tt0096056', 'movie', 'Crime and Punishment', 2002.0, None, 126), ('tt0100275', 'movie', 'The Wandering Soap Opera', 2017.0, None, 80), ('tt0108549', 'movie', 'West from North Goes South', 2004.0, None, 96), ('tt0113026', 'movie', 'The Fantasticks', 2000.0, None, 86)  ... displaying 10 of 82666 total bound parameter sets ...  ('tt9916190', 'movie', 'Safeguard', 2020.0, None, 95), ('tt9916362', 'movie', 'Coven', 2020.0, None, 92))
# 2022-09-26 16:30:47,469 INFO sqlalchemy.engine.Engine COMMIT
# 2022-09-26 16:30:47,475 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("title_ratings")
# 2022-09-26 16:30:47,475 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2022-09-26 16:30:47,476 INFO sqlalchemy.engine.Engine PRAGMA temp.table_info("title_ratings")
# 2022-09-26 16:30:47,476 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2022-09-26 16:30:47,477 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2022-09-26 16:30:47,477 INFO sqlalchemy.engine.Engine
# CREATE TABLE title_ratings (
# 	tconst VARCHAR(11),
# 	"averageRating" FLOAT,
# 	"numVotes" INTEGER
# )
#
#
# 2022-09-26 16:30:47,478 INFO sqlalchemy.engine.Engine [no key 0.00036s] ()
# 2022-09-26 16:30:47,481 INFO sqlalchemy.engine.Engine COMMIT
# 2022-09-26 16:30:47,657 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2022-09-26 16:30:48,534 INFO sqlalchemy.engine.Engine INSERT INTO title_ratings (tconst, "averageRating", "numVotes") VALUES (?, ?, ?)
# 2022-09-26 16:30:48,534 INFO sqlalchemy.engine.Engine [generated in 0.72074s] (('tt0000001', 5.7, 1910), ('tt0000002', 5.8, 257), ('tt0000005', 6.2, 2530), ('tt0000006', 5.1, 173), ('tt0000007', 5.4, 789), ('tt0000008', 5.4, 2052), ('tt0000009', 5.2, 199), ('tt0000010', 6.9, 6928)  ... displaying 10 of 477222 total bound parameter sets ...  ('tt9916428', 3.8, 14), ('tt9916720', 5.2, 258))
# 2022-09-26 16:30:48,827 INFO sqlalchemy.engine.Engine COMMIT
# 2022-09-26 16:30:48,838 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("title_genres")
# 2022-09-26 16:30:48,838 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2022-09-26 16:30:48,839 INFO sqlalchemy.engine.Engine PRAGMA temp.table_info("title_genres")
# 2022-09-26 16:30:48,839 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2022-09-26 16:30:48,840 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2022-09-26 16:30:48,840 INFO sqlalchemy.engine.Engine
# CREATE TABLE title_genres (
# 	tconst VARCHAR(11),
# 	genre_id INTEGER
# )
#
#
# 2022-09-26 16:30:48,840 INFO sqlalchemy.engine.Engine [no key 0.00029s] ()
# 2022-09-26 16:30:48,842 INFO sqlalchemy.engine.Engine COMMIT
# 2022-09-26 16:30:48,850 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2022-09-26 16:30:49,190 INFO sqlalchemy.engine.Engine INSERT INTO title_genres (tconst, genre_id) VALUES (?, ?)
# 2022-09-26 16:30:49,191 INFO sqlalchemy.engine.Engine [generated in 0.29723s] (('tt0035423', 5), ('tt0035423', 9), ('tt0035423', 18), ('tt0062336', 7), ('tt0069049', 7), ('tt0088751', 5), ('tt0088751', 12), ('tt0088751', 19)  ... displaying 10 of 154505 total bound parameter sets ...  ('tt9916362', 7), ('tt9916362', 11))
# 2022-09-26 16:30:49,267 INFO sqlalchemy.engine.Engine COMMIT
# 2022-09-26 16:30:49,275 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("genres")
# 2022-09-26 16:30:49,276 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2022-09-26 16:30:49,276 INFO sqlalchemy.engine.Engine PRAGMA temp.table_info("genres")
# 2022-09-26 16:30:49,277 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2022-09-26 16:30:49,278 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2022-09-26 16:30:49,278 INFO sqlalchemy.engine.Engine
# CREATE TABLE genres (
# 	"Genre_ID" BIGINT,
# 	"Genre_Name" TEXT
# )
#
#
# 2022-09-26 16:30:49,278 INFO sqlalchemy.engine.Engine [no key 0.00032s] ()
# 2022-09-26 16:30:49,292 INFO sqlalchemy.engine.Engine CREATE INDEX "ix_genres_Genre_ID" ON genres ("Genre_ID")
# 2022-09-26 16:30:49,295 INFO sqlalchemy.engine.Engine [no key 0.00264s] ()
# 2022-09-26 16:30:49,296 INFO sqlalchemy.engine.Engine COMMIT
# 2022-09-26 16:30:49,299 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2022-09-26 16:30:49,300 INFO sqlalchemy.engine.Engine INSERT INTO genres ("Genre_ID", "Genre_Name") VALUES (?, ?)
# 2022-09-26 16:30:49,301 INFO sqlalchemy.engine.Engine [generated in 0.00083s] ((0, 'Action'), (1, 'Adult'), (2, 'Adventure'), (3, 'Animation'), (4, 'Biography'), (5, 'Comedy'), (6, 'Crime'), (7, 'Drama')  ... displaying 10 of 26 total bound parameter sets ...  (24, 'War'), (25, 'Western'))
# 2022-09-26 16:30:49,302 INFO sqlalchemy.engine.Engine COMMIT
# 2022-09-26 16:30:49,324 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("tmdb_data")
# 2022-09-26 16:30:49,324 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2022-09-26 16:30:49,328 INFO sqlalchemy.engine.Engine PRAGMA temp.table_info("tmdb_data")
# 2022-09-26 16:30:49,329 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2022-09-26 16:30:49,331 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2022-09-26 16:30:49,331 INFO sqlalchemy.engine.Engine
# CREATE TABLE tmdb_data (
# 	"index" BIGINT,
# 	imdb_id TEXT,
# 	adult FLOAT,
# 	backdrop_path TEXT,
# 	belongs_to_collection TEXT,
# 	budget FLOAT,
# 	genres TEXT,
# 	homepage TEXT,
# 	id FLOAT,
# 	original_language TEXT,
# 	original_title TEXT,
# 	overview TEXT,
# 	popularity FLOAT,
# 	poster_path TEXT,
# 	production_companies TEXT,
# 	production_countries TEXT,
# 	release_date TEXT,
# 	revenue FLOAT,
# 	runtime FLOAT,
# 	spoken_languages TEXT,
# 	status TEXT,
# 	tagline TEXT,
# 	title TEXT,
# 	video FLOAT,
# 	vote_average FLOAT,
# 	vote_count FLOAT,
# 	certification TEXT
# )
#
#
# 2022-09-26 16:30:49,332 INFO sqlalchemy.engine.Engine [no key 0.00073s] ()
# 2022-09-26 16:30:49,334 INFO sqlalchemy.engine.Engine CREATE INDEX ix_tmdb_data_index ON tmdb_data ("index")
# 2022-09-26 16:30:49,334 INFO sqlalchemy.engine.Engine [no key 0.00032s] ()
# 2022-09-26 16:30:49,335 INFO sqlalchemy.engine.Engine COMMIT
# 2022-09-26 16:30:49,340 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2022-09-26 16:30:49,345 INFO sqlalchemy.engine.Engine INSERT INTO tmdb_data ("index", imdb_id, adult, backdrop_path, belongs_to_collection, budget, genres, homepage, id, original_language, original_title, overview, popularity, poster_path, production_companies, production_countries, release_date, revenue, runtime, spoken_languages, status, tagline, title, video, vote_average, vote_count, certification) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2022-09-26 16:30:49,345 INFO sqlalchemy.engine.Engine [generated in 0.00330s] ((0, 'tt0118694', 0.0, '/n4GJFGzsc7NinI1VeGDXIcQjtU2.jpg', None, 150000.0, "[{'id': 18, 'name': 'Drama'}, {'id': 10749, 'name': 'Romance'}]", 'http://www.wkw-inthemoodforlove.com/', 843.0, 'cn', '花樣年華', 'Hong Kong, 1962: Chow Mo-Wan and Su Li-Zhen move into neighboring apartments on the same day. Their encounters are formal and polite—until a discovery about their spouses creates an intimate bond between them.', 26.816, '/iYypPT4bhqXfq1b6EnmxvRt6b2Y.jpg', "[{'id': 539, 'logo_path': None, 'name': 'Block 2 Pictures', 'origin_country': ''}, {'id': 26492, 'logo_path': None, 'name': 'Jet Tone Films', 'origin ... (29 characters truncated) ... 54, 'logo_path': None, 'name': 'Orly Films', 'origin_country': ''}, {'id': 148855, 'logo_path': None, 'name': 'Paradis Films', 'origin_country': ''}]", "[{'iso_3166_1': 'FR', 'name': 'France'}, {'iso_3166_1': 'HK', 'name': 'Hong Kong'}]", '2000-09-29', 12854953.0, 99.0, "[{'english_name': 'Cantonese', 'iso_639_1': 'cn', 'name': '广州话 / 廣州話'}, {'english_name': 'French', 'iso_639_1': 'fr', 'name': 'Français'}, {'english_name': 'Spanish', 'iso_639_1': 'es', 'name': 'Español'}]", 'Released', 'Feel the heat, keep the feeling burning, let the sensation explode.', 'In the Mood for Love', 0.0, 8.108, 1982.0, 'PG'), (1, 'tt0119273', 0.0, '/f5C03doOWiauu37bToKXtpgP5bS.jpg', "{'id': 141086, 'name': 'Heavy Metal Collection', 'poster_path': '/tgPpYcsjSo1DK0wublqYItYDwSW.jpg', 'backdrop_path': '/iao9hIahX41T1Lxpa5h62J28rQF.jpg'}", 15000000.0, "[{'id': 28, 'name': 'Action'}, {'id': 12, 'name': 'Adventure'}, {'id': 16, 'name': 'Animation'}, {'id': 14, 'name': 'Fantasy'}, {'id': 878, 'name': 'Science Fiction'}]", None, 16225.0, 'en', 'Heavy Metal 2000', "Upon discovery of a shard of what could be the Loc-Nar, a miner named Tyler becomes possessed with an insatiable hunger for power and a thirst for im ... (86 characters truncated) ... nd kidnaps a beautiful young woman. His only mistake is that he doesn't kill her sister, Julie, who then sets out on a mission of rescue and revenge.", 12.815, '/mzOgKYOXiuwE5DIfagFs34bOb3J.jpg', "[{'id': 5, 'logo_path': '/71BqEFAF4V3qjjMPCpLuyJFB9A.png', 'name': 'Columbia Pictures', 'origin_country': 'US'}, {'id': 2216, 'logo_path': None, 'nam ... (62 characters truncated) ... go_path': None, 'name': 'Cine Groupe', 'origin_country': ''}, {'id': 91006, 'logo_path': None, 'name': 'Das Werk Productions', 'origin_country': ''}]", "[{'iso_3166_1': 'CA', 'name': 'Canada'}, {'iso_3166_1': 'DE', 'name': 'Germany'}]", '2000-04-19', 0.0, 88.0, "[{'english_name': 'English', 'iso_639_1': 'en', 'name': 'English'}]", 'Released', 'not to survive the fight in the external world without inner strength', 'Heavy Metal 2000', 0.0, 6.11, 159.0, 'R'), (2, 'tt0120467', 0.0, '/knok3mNReKqPTplnnqz7E4dd7mD.jpg', None, 120000.0, "[{'id': 18, 'name': 'Drama'}, {'id': 27, 'name': 'Horror'}, {'id': 53, 'name': 'Thriller'}, {'id': 80, 'name': 'Crime'}]", None, 19085.0, 'en', 'Vulgar', "Vulgar is about a man who is a children's clown but has not been getting much luck lately. He lives in a cheap apartment which he can't even afford.  ... (74 characters truncated) ...  He has a nagging mother who lives in a nursing home, and his best friend is a moocher. One day he comes up with the idea to become a bachelor clown.", 5.454, '/aLdezroGbHDP0w0jOLwxXjgrgma.jpg', "[{'id': 16934, 'logo_path': '/7HEUbdTlFQWf4SKidP8S29yFgoW.png', 'name': 'View Askew Productions', 'origin_country': 'US'}, {'id': 102045, 'logo_path' ... (1 characters truncated) ...  None, 'name': 'Chango Productions', 'origin_country': ''}, {'id': 102046, 'logo_path': None, 'name': 'Shongo Filmworks Ltd.', 'origin_country': ''}]", "[{'iso_3166_1': 'US', 'name': 'United States of America'}]", '2002-04-26', 14904.0, 87.0, "[{'english_name': 'English', 'iso_639_1': 'en', 'name': 'English'}]", 'Released', 'Everyone loves a clown... some more than others.', 'Vulgar', 0.0, 5.4, 42.0,  ...
# 2022-09-26 16:30:49,348 INFO sqlalchemy.engine.Engine COMMIT
# 384

# %%
engine.execute('ALTER TABLE title_basics ADD PRIMARY KEY (`tconst`);')
# Out:
# 2022-09-26 16:32:24,748 INFO sqlalchemy.engine.Engine ALTER TABLE title_basics ADD PRIMARY KEY (`tconst`);
# 2022-09-26 16:32:24,748 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2022-09-26 16:32:24,753 INFO sqlalchemy.engine.Engine ROLLBACK
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File ~/opt/miniconda3/envs/dojo-env/lib/python3.8/site-packages/sqlalchemy/engine/base.py:1819, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1818     if not evt_handled:
# -> 1819         self.dialect.do_execute(
#    1820             cursor, statement, parameters, context
#    1821         )
#    1823 if self._has_events or self.engine._has_events:
#
# File ~/opt/miniconda3/envs/dojo-env/lib/python3.8/site-packages/sqlalchemy/engine/default.py:732, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     731 def do_execute(self, cursor, statement, parameters, context=None):
# --> 732     cursor.execute(statement, parameters)
#
# OperationalError: near "PRIMARY": syntax error
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# Input In [167], in <cell line: 1>()
# ----> 1 engine.execute('ALTER TABLE title_basics ADD PRIMARY KEY (`tconst`);')
#
# File <string>:2, in execute(self, statement, *multiparams, **params)
#
# File ~/opt/miniconda3/envs/dojo-env/lib/python3.8/site-packages/sqlalchemy/util/deprecations.py:401, in _decorate_with_warning.<locals>.warned(fn, *args, **kwargs)
#     399 if not skip_warning:
#     400     _warn_with_version(message, version, wtype, stacklevel=3)
# --> 401 return fn(*args, **kwargs)
#
# File ~/opt/miniconda3/envs/dojo-env/lib/python3.8/site-packages/sqlalchemy/engine/base.py:3176, in Engine.execute(self, statement, *multiparams, **params)
#    3158 """Executes the given construct and returns a
#    3159 :class:`_engine.CursorResult`.
#    3160
#    (...)
#    3173
#    3174 """
#    3175 connection = self.connect(close_with_result=True)
# -> 3176 return connection.execute(statement, *multiparams, **params)
#
# File ~/opt/miniconda3/envs/dojo-env/lib/python3.8/site-packages/sqlalchemy/engine/base.py:1291, in Connection.execute(self, statement, *multiparams, **params)
#    1282 if isinstance(statement, util.string_types):
#    1283     util.warn_deprecated_20(
#    1284         "Passing a string to Connection.execute() is "
#    1285         "deprecated and will be removed in version 2.0.  Use the "
#    (...)
#    1288         "driver-level SQL string."
#    1289     )
# -> 1291     return self._exec_driver_sql(
#    1292         statement,
#    1293         multiparams,
#    1294         params,
#    1295         _EMPTY_EXECUTION_OPTS,
#    1296         future=False,
#    1297     )
#    1299 try:
#    1300     meth = statement._execute_on_connection
#
# File ~/opt/miniconda3/envs/dojo-env/lib/python3.8/site-packages/sqlalchemy/engine/base.py:1595, in Connection._exec_driver_sql(self, statement, multiparams, params, execution_options, future)
#    1585         (
#    1586             statement,
#    1587             distilled_params,
#    (...)
#    1591             statement, distilled_parameters, execution_options
#    1592         )
#    1594 dialect = self.dialect
# -> 1595 ret = self._execute_context(
#    1596     dialect,
#    1597     dialect.execution_ctx_cls._init_statement,
#    1598     statement,
#    1599     distilled_parameters,
#    1600     execution_options,
#    1601     statement,
#    1602     distilled_parameters,
#    1603 )
#    1605 if not future:
#    1606     if self._has_events or self.engine._has_events:
#
# File ~/opt/miniconda3/envs/dojo-env/lib/python3.8/site-packages/sqlalchemy/engine/base.py:1862, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1859             branched.close()
#    1861 except BaseException as e:
# -> 1862     self._handle_dbapi_exception(
#    1863         e, statement, parameters, cursor, context
#    1864     )
#    1866 return result
#
# File ~/opt/miniconda3/envs/dojo-env/lib/python3.8/site-packages/sqlalchemy/engine/base.py:2043, in Connection._handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    2041     util.raise_(newraise, with_traceback=exc_info[2], from_=e)
#    2042 elif should_wrap:
# -> 2043     util.raise_(
#    2044         sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#    2045     )
#    2046 else:
#    2047     util.raise_(exc_info[1], with_traceback=exc_info[2])
#
# File ~/opt/miniconda3/envs/dojo-env/lib/python3.8/site-packages/sqlalchemy/util/compat.py:208, in raise_(***failed resolving arguments***)
#     205     exception.__cause__ = replace_context
#     207 try:
# --> 208     raise exception
#     209 finally:
#     210     # credit to
#     211     # https://cosmicpercolator.com/2016/01/13/exception-leaks-in-python-2-and-3/
#     212     # as the __traceback__ object creates a cycle
#     213     del exception, replace_context, from_, with_traceback
#
# File ~/opt/miniconda3/envs/dojo-env/lib/python3.8/site-packages/sqlalchemy/engine/base.py:1819, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1817                 break
#    1818     if not evt_handled:
# -> 1819         self.dialect.do_execute(
#    1820             cursor, statement, parameters, context
#    1821         )
#    1823 if self._has_events or self.engine._has_events:
#    1824     self.dispatch.after_cursor_execute(
#    1825         self,
#    1826         cursor,
#    (...)
#    1830         context.executemany,
#    1831     )
#
# File ~/opt/miniconda3/envs/dojo-env/lib/python3.8/site-packages/sqlalchemy/engine/default.py:732, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     731 def do_execute(self, cursor, statement, parameters, context=None):
# --> 732     cursor.execute(statement, parameters)
#
# OperationalError: (sqlite3.OperationalError) near "PRIMARY": syntax error
# [SQL: ALTER TABLE title_basics ADD PRIMARY KEY (`tconst`);]
# (Background on this error at: https://sqlalche.me/e/14/e3q8)
