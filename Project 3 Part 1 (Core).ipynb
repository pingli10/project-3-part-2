# %%
import pandas as pd
import numpy as np

# %%
basics_url="https://datasets.imdbws.com/title.basics.tsv.gz"
akas_url = "https://datasets.imdbws.com/title.akas.tsv.gz"
ratings_url = "https://datasets.imdbws.com/title.ratings.tsv.gz"

# %%
basics = pd.read_csv(basics_url, sep='\t', low_memory=False)
akas = pd.read_csv(akas_url, sep='\t', low_memory=False)
ratings = pd.read_csv(ratings_url, sep='\t', low_memory=False)

# %%
basics=basics.replace({'\\N':np.nan})
akas=akas.replace({'\\N':np.nan})
ratings=ratings.replace({'\\N':np.nan})

# %%
#basics.dropna(subset=['runtimeMinutes','genres'],inplace = True )
#basics = basics[basics['var2'].isnull()]
basics = basics.loc[~pd.isnull(basics.genres)]
basics = basics.loc[~pd.isnull(basics.runtimeMinutes)]

# %%
# Exclude movies that are included in the documentary category.
basics = basics[~basics['genres'].str.contains('Documentary',na=False)]

# %%
basics
# Out:
#             tconst  titleType                primaryTitle  \
# 1        tt0000002      short      Le clown et ses chiens
# 2        tt0000003      short              Pauvre Pierrot
# 3        tt0000004      short                 Un bon bock
# 4        tt0000005      short            Blacksmith Scene
# 5        tt0000006      short           Chinese Opium Den
# ...            ...        ...                         ...
# 9246329  tt9916720      short                   The Nun 2
# 9246349  tt9916766  tvEpisode              Episode #10.15
# 9246384  tt9916840  tvEpisode  Horrid Henry's Comic Caper
# 9246391  tt9916856      short                    The Wind
# 9246392  tt9916880  tvEpisode   Horrid Henry Knows It All
#
#                       originalTitle isAdult startYear endYear runtimeMinutes  \
# 1            Le clown et ses chiens       0      1892     NaN              5
# 2                    Pauvre Pierrot       0      1892     NaN              4
# 3                       Un bon bock       0      1892     NaN             12
# 4                  Blacksmith Scene       0      1893     NaN              1
# 5                 Chinese Opium Den       0      1894     NaN              1
# ...                             ...     ...       ...     ...            ...
# 9246329                   The Nun 2       0      2019     NaN             10
# 9246349              Episode #10.15       0      2019     NaN             43
# 9246384  Horrid Henry's Comic Caper       0      2014     NaN             11
# 9246391                    The Wind       0      2015     NaN             27
# 9246392   Horrid Henry Knows It All       0      2014     NaN             10
#
#                               genres
# 1                    Animation,Short
# 2           Animation,Comedy,Romance
# 3                    Animation,Short
# 4                       Comedy,Short
# 5                              Short
# ...                              ...
# 9246329        Comedy,Horror,Mystery
# 9246349  Family,Game-Show,Reality-TV
# 9246384   Adventure,Animation,Comedy
# 9246391                        Short
# 9246392   Adventure,Animation,Comedy
#
# [2029857 rows x 9 columns]

# %%
# Filter the basics table down to only include the US by using the filter akas dataframe
ak_keeper = akas['region'].isin(['US'])

# %%
akas = akas[ak_keeper]

# %%
akas
# Out:
#             titleId  ordering                          title region language  \
# 5         tt0000001         6                     Carmencita     US      NaN
# 14        tt0000002         7         The Clown and His Dogs     US      NaN
# 33        tt0000005        10               Blacksmith Scene     US      NaN
# 36        tt0000005         1            Blacksmithing Scene     US      NaN
# 41        tt0000005         6            Blacksmith Scene #1     US      NaN
# ...             ...       ...                            ...    ...      ...
# 33279469  tt9916702         1  Loving London: The Playground     US      NaN
# 33279506  tt9916720        10                The Demonic Nun     US      NaN
# 33279508  tt9916720        12                      The Nun 2     US      NaN
# 33279525  tt9916756         1       Pretty Pretty Black Girl     US      NaN
# 33279541  tt9916764         1                             38     US      NaN
#
#                 types             attributes isOriginalTitle
# 5         imdbDisplay                    NaN               0
# 14                NaN  literal English title               0
# 33        imdbDisplay                    NaN               0
# 36        alternative                    NaN               0
# 41        alternative                    NaN               0
# ...               ...                    ...             ...
# 33279469          NaN                    NaN               0
# 33279506           tv                    NaN               0
# 33279508  imdbDisplay                    NaN               0
# 33279525  imdbDisplay                    NaN               0
# 33279541  imdbDisplay                    NaN               0
#
# [1353217 rows x 8 columns]

# %%
basics = basics[basics['titleType']=='movie']
basics
# Out:
#             tconst titleType                    primaryTitle  \
# 8        tt0000009     movie                      Miss Jerry
# 570      tt0000574     movie     The Story of the Kelly Gang
# 587      tt0000591     movie                The Prodigal Son
# 672      tt0000679     movie  The Fairylogue and Radio-Plays
# 1172     tt0001184     movie         Don Juan de Serrallonga
# ...            ...       ...                             ...
# 9246065  tt9916170     movie                   The Rehearsal
# 9246074  tt9916190     movie                       Safeguard
# 9246113  tt9916270     movie        Il talento del calabrone
# 9246158  tt9916362     movie                           Coven
# 9246242  tt9916538     movie             Kuambil Lagi Hatiku
#
#                           originalTitle isAdult startYear endYear  \
# 8                            Miss Jerry       0      1894     NaN
# 570         The Story of the Kelly Gang       0      1906     NaN
# 587                   L'enfant prodigue       0      1907     NaN
# 672      The Fairylogue and Radio-Plays       0      1908     NaN
# 1172            Don Juan de Serrallonga       0      1910     NaN
# ...                                 ...     ...       ...     ...
# 9246065                        O Ensaio       0      2019     NaN
# 9246074                       Safeguard       0      2020     NaN
# 9246113        Il talento del calabrone       0      2020     NaN
# 9246158                        Akelarre       0      2020     NaN
# 9246242             Kuambil Lagi Hatiku       0      2019     NaN
#
#         runtimeMinutes                      genres
# 8                   45                     Romance
# 570                 70  Action,Adventure,Biography
# 587                 90                       Drama
# 672                120           Adventure,Fantasy
# 1172                58             Adventure,Drama
# ...                ...                         ...
# 9246065             51                       Drama
# 9246074             95   Action,Adventure,Thriller
# 9246113             84                    Thriller
# 9246158             92               Drama,History
# 9246242            123                       Drama
#
# [280666 rows x 9 columns]

# %%
keepers = basics['tconst'].isin(akas['titleId'])
keeper =ratings['tconst'].isin(akas['titleId'])
keepers
# Out:
# 8           True
# 570         True
# 587         True
# 672         True
# 1172       False
#            ...
# 9246065     True
# 9246074     True
# 9246113    False
# 9246158     True
# 9246242    False
# Name: tconst, Length: 280666, dtype: bool

# %%
basics = basics[keepers]
ratings = ratings[keeper]
basics
# Out:
#             tconst titleType                    primaryTitle  \
# 8        tt0000009     movie                      Miss Jerry
# 570      tt0000574     movie     The Story of the Kelly Gang
# 587      tt0000591     movie                The Prodigal Son
# 672      tt0000679     movie  The Fairylogue and Radio-Plays
# 1273     tt0001285     movie               The Life of Moses
# ...            ...       ...                             ...
# 9245529  tt9914942     movie          Life Without Sara Amat
# 9245925  tt9915872     movie            The Last White Witch
# 9246065  tt9916170     movie                   The Rehearsal
# 9246074  tt9916190     movie                       Safeguard
# 9246158  tt9916362     movie                           Coven
#
#                           originalTitle isAdult startYear endYear  \
# 8                            Miss Jerry       0      1894     NaN
# 570         The Story of the Kelly Gang       0      1906     NaN
# 587                   L'enfant prodigue       0      1907     NaN
# 672      The Fairylogue and Radio-Plays       0      1908     NaN
# 1273                  The Life of Moses       0      1909     NaN
# ...                                 ...     ...       ...     ...
# 9245529      La vida sense la Sara Amat       0      2019     NaN
# 9245925       My Girlfriend is a Wizard       0      2019     NaN
# 9246065                        O Ensaio       0      2019     NaN
# 9246074                       Safeguard       0      2020     NaN
# 9246158                        Akelarre       0      2020     NaN
#
#         runtimeMinutes                      genres
# 8                   45                     Romance
# 570                 70  Action,Adventure,Biography
# 587                 90                       Drama
# 672                120           Adventure,Fantasy
# 1273                50      Biography,Drama,Family
# ...                ...                         ...
# 9245529             74                       Drama
# 9245925             97        Comedy,Drama,Fantasy
# 9246065             51                       Drama
# 9246074             95   Action,Adventure,Thriller
# 9246158             92               Drama,History
#
# [153848 rows x 9 columns]

# %%
basics = basics[(basics['startYear'] >= '2000') & (basics['startYear'] <= '2022')]
basics
# Out:
#             tconst titleType  \
# 34792    tt0035423     movie
# 61094    tt0062336     movie
# 67640    tt0069049     movie
# 86771    tt0088751     movie
# 93907    tt0096056     movie
# ...            ...       ...
# 9245529  tt9914942     movie
# 9245925  tt9915872     movie
# 9246065  tt9916170     movie
# 9246074  tt9916190     movie
# 9246158  tt9916362     movie
#
#                                               primaryTitle  \
# 34792                                       Kate & Leopold
# 61094    The Tango of the Widower and Its Distorting Mi...
# 67640                           The Other Side of the Wind
# 86771                                    The Naked Monster
# 93907                                 Crime and Punishment
# ...                                                    ...
# 9245529                             Life Without Sara Amat
# 9245925                               The Last White Witch
# 9246065                                      The Rehearsal
# 9246074                                          Safeguard
# 9246158                                              Coven
#
#                                      originalTitle isAdult startYear endYear  \
# 34792                               Kate & Leopold       0      2001     NaN
# 61094    El Tango del Viudo y Su Espejo Deformante       0      2020     NaN
# 67640                   The Other Side of the Wind       0      2018     NaN
# 86771                            The Naked Monster       0      2005     NaN
# 93907                         Crime and Punishment       0      2002     NaN
# ...                                            ...     ...       ...     ...
# 9245529                 La vida sense la Sara Amat       0      2019     NaN
# 9245925                  My Girlfriend is a Wizard       0      2019     NaN
# 9246065                                   O Ensaio       0      2019     NaN
# 9246074                                  Safeguard       0      2020     NaN
# 9246158                                   Akelarre       0      2020     NaN
#
#         runtimeMinutes                     genres
# 34792              118     Comedy,Fantasy,Romance
# 61094               70                      Drama
# 67640              122                      Drama
# 86771              100       Comedy,Horror,Sci-Fi
# 93907              126                      Drama
# ...                ...                        ...
# 9245529             74                      Drama
# 9245925             97       Comedy,Drama,Fantasy
# 9246065             51                      Drama
# 9246074             95  Action,Adventure,Thriller
# 9246158             92              Drama,History
#
# [82666 rows x 9 columns]

# %%
# example making new folder with os
import os
os.makedirs('Data/',exist_ok=True) 
# Confirm folder created
os.listdir("Data/")
# Out:
# []

# %%
## Save current dataframe to file.
basics.to_csv("Data/title_basics.csv.gz",compression='gzip',index=False)

# %%
# Open saved file and preview again
basics = pd.read_csv("Data/title_basics.csv.gz", low_memory = False)
basics.head()
# Out:
#       tconst titleType                                       primaryTitle  \
# 0  tt0035423     movie                                     Kate & Leopold
# 1  tt0062336     movie  The Tango of the Widower and Its Distorting Mi...
# 2  tt0069049     movie                         The Other Side of the Wind
# 3  tt0088751     movie                                  The Naked Monster
# 4  tt0096056     movie                               Crime and Punishment
#
#                                originalTitle  isAdult  startYear  endYear  \
# 0                             Kate & Leopold        0       2001      NaN
# 1  El Tango del Viudo y Su Espejo Deformante        0       2020      NaN
# 2                 The Other Side of the Wind        0       2018      NaN
# 3                          The Naked Monster        0       2005      NaN
# 4                       Crime and Punishment        0       2002      NaN
#
#    runtimeMinutes                  genres
# 0             118  Comedy,Fantasy,Romance
# 1              70                   Drama
# 2             122                   Drama
# 3             100    Comedy,Horror,Sci-Fi
# 4             126                   Drama

# %%
## Save current dataframe to file.
akas.to_csv("Data/title.akas.tsv.gz",compression='gzip',index=False)

# %%
# Open saved file and preview again
akas = pd.read_csv("Data/title.akas.tsv.gz", low_memory = False)
akas.head()
# Out:
#      titleId  ordering                   title region language        types  \
# 0  tt0000001         6              Carmencita     US      NaN  imdbDisplay
# 1  tt0000002         7  The Clown and His Dogs     US      NaN          NaN
# 2  tt0000005        10        Blacksmith Scene     US      NaN  imdbDisplay
# 3  tt0000005         1     Blacksmithing Scene     US      NaN  alternative
# 4  tt0000005         6     Blacksmith Scene #1     US      NaN  alternative
#
#               attributes  isOriginalTitle
# 0                    NaN              0.0
# 1  literal English title              0.0
# 2                    NaN              0.0
# 3                    NaN              0.0
# 4                    NaN              0.0

# %%
## Save current dataframe to file.
ratings.to_csv("Data/title.ratings.tsv.gz",compression='gzip',index=False)

# %%
# Open saved file and preview again
ratings = pd.read_csv("Data/title.ratings.tsv.gz", low_memory = False)
ratings.head()
# Out:
#       tconst  averageRating  numVotes
# 0  tt0000001            5.7      1910
# 1  tt0000002            5.8       257
# 2  tt0000005            6.2      2530
# 3  tt0000006            5.1       173
# 4  tt0000007            5.4       789
